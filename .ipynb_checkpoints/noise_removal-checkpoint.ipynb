# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from skimage import util, img_as_float, img_as_ubyte, color
from skimage.restoration import denoise_wavelet, wiener as wiener_filter_sk
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim

from scipy.signal import wiener as wiener_filter_scipy
import pywt
import pandas as pd

# %%
def load_image(image_path):
    image_bgr = cv2.imread(image_path)
    if image_bgr is None:
        raise FileNotFoundError(f"Image file not found: {image_path}")
    return cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

def add_synthetic_noise(image):
    image_float = img_as_float(image)
    noisy = util.random_noise(image_float, mode='gaussian', var=0.01)
    noisy = util.random_noise(noisy, mode='s&p', amount=0.02)
    return img_as_ubyte(noisy)

def apply_denoising_methods(noisy_image):
    methods = {}

    gray_noisy = color.rgb2gray(noisy_image)
    psf = np.ones((5, 5)) / 25
    wiener_gray = wiener_filter_sk(gray_noisy, psf, balance=0.01, clip=True)
    wiener_gray = np.clip(wiener_gray, 0, 1)
    wiener_uint8 = img_as_ubyte(wiener_gray)
    methods["Wiener Filter"] = cv2.cvtColor(wiener_uint8, cv2.COLOR_GRAY2RGB)

    methods["Median Filter"] = cv2.medianBlur(noisy_image, 3)
    methods["Non-Local Means"] = cv2.fastNlMeansDenoisingColored(noisy_image, None, 10, 10, 7, 21)
    methods["Bilateral Filter"] = cv2.bilateralFilter(noisy_image, 9, 75, 75)

    wavelet_filtered_float = denoise_wavelet(noisy_image, wavelet='db1', mode='soft',
                                             channel_axis=2, rescale_sigma=True)
    methods["Wavelet Filter"] = img_as_ubyte(wavelet_filtered_float)

    median_then_nlm = cv2.fastNlMeansDenoisingColored(methods["Median Filter"], None, 10, 10, 7, 21)
    methods["Median + NLM"] = median_then_nlm

    bilateral_then_wavelet_float = denoise_wavelet(methods["Bilateral Filter"], wavelet='db1', mode='soft',
                                                   channel_axis=2, rescale_sigma=True)
    methods["Bilateral + Wavelet"] = img_as_ubyte(bilateral_then_wavelet_float)

    return methods

# %%
image_paths = ["H-1 (Potential future star-forming regions).jpg", "H-2 (Active star formation).jpg"]

for path in image_paths:
    print(f"\n--- Processing: {path} ---")
    
    # Load and show original image
    orig = load_image(path)
    plt.figure(figsize=(5,5))
    plt.imshow(orig)
    plt.title(f"Original Image: {path}")
    plt.axis("off")
    plt.show()
    
    # Add noise
    noisy = add_synthetic_noise(orig)
    plt.figure(figsize=(5,5))
    plt.imshow(noisy)
    plt.title(f"Noisy Image: {path}")
    plt.axis("off")
    plt.show()
    
    # Apply filters
    methods = apply_denoising_methods(noisy)
    methods["Noisy Input"] = noisy
    
    # Show all results
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))
    axes = axes.flatten()
    for ax, (title, image) in zip(axes, methods.items()):
        ax.imshow(image)
        ax.set_title(title)
        ax.axis("off")
    plt.suptitle(f"Denoising Results for {path}", fontsize=16)
    plt.tight_layout()
    plt.show()

    # Evaluate PSNR & SSIM
    orig_gray = color.rgb2gray(orig)
    results = []
    for title, image in methods.items():
        if title == "Noisy Input":
            continue
        image_gray = color.rgb2gray(image) if image.ndim == 3 else image
        psnr_val = psnr(orig_gray, image_gray, data_range=orig_gray.max() - orig_gray.min())
        ssim_val = ssim(orig_gray, image_gray, data_range=orig_gray.max() - orig_gray.min())
        results.append((title, psnr_val, ssim_val))

    df = pd.DataFrame(results, columns=["Method", "PSNR", "SSIM"])
    df_sorted = df.sort_values(by="PSNR", ascending=False).reset_index(drop=True)
    print(df_sorted)
# Out:
# --- Processing: H-1 (Potential future star-forming regions).jpg ---
#                 Method       PSNR      SSIM
# 0         Median + NLM  31.291301  0.761335
# 1        Median Filter  28.659632  0.582695
# 2       Wavelet Filter  26.655498  0.520668
# 3  Bilateral + Wavelet  26.161081  0.557808
# 4     Bilateral Filter  25.613648  0.520973
# 5      Non-Local Means  21.958555  0.349643
# 6        Wiener Filter  18.098361  0.137489
#
# --- Processing: H-2 (Active star formation).jpg ---
#                 Method       PSNR      SSIM
# 0         Median + NLM  31.293771  0.849622
# 1        Median Filter  28.778099  0.590650
# 2       Wavelet Filter  26.481025  0.519309
# 3  Bilateral + Wavelet  26.031006  0.552234
# 4     Bilateral Filter  25.547302  0.510470
# 5      Non-Local Means  21.219717  0.255782
# 6        Wiener Filter  18.154184  0.134140
